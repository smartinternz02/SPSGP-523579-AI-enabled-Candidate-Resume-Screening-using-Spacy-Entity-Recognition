# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Task 1: Read the dataset and do data pre-processing
data = pd.read_csv('/drug200.csv')

# %%
# Split the dataset into features and labels
features = data.drop('Drug', axis=1)
labels = data['Drug']

# %%
# Convert categorical features to numerical using LabelEncoder
categorical_features = ['Sex', 'BP', 'Cholesterol']
label_encoder = LabelEncoder()
for feature in categorical_features:
    features[feature] = label_encoder.fit_transform(features[feature])

# %%
# Convert labels to numerical values
label_encoder.fit(labels)
labels = label_encoder.transform(labels)

# %%
# Normalize the numerical features
numerical_features = ['Age', 'Na_to_K']
scaler = StandardScaler()
features[numerical_features] = scaler.fit_transform(features[numerical_features])

# %%
# Task 2: Build the ANN model
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=5))  # Input layer with 5 features
model.add(Dense(128, activation='relu'))  # Hidden layer 1
model.add(Dense(64, activation='relu'))  # Hidden layer 2
model.add(Dense(32, activation='relu'))  # Hidden layer 3
model.add(Dense(5, activation='softmax'))  # Output layer with 5 classes

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Task 3: Test the model with random data
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 6ms/step - loss: 1.5257 - accuracy: 0.2688
# Epoch 2/100
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3177 - accuracy: 0.6313
# Epoch 3/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.1275 - accuracy: 0.6625
# Epoch 4/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9637 - accuracy: 0.6812
# Epoch 5/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8251 - accuracy: 0.7125
# Epoch 6/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7214 - accuracy: 0.7312
# Epoch 7/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6266 - accuracy: 0.7688
# Epoch 8/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5534 - accuracy: 0.8250
# Epoch 9/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4818 - accuracy: 0.8500
# Epoch 10/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4282 - accuracy: 0.8750
# Epoch 11/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3723 - accuracy: 0.8875
# Epoch 12/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.9062
# Epoch 13/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.9250
# Epoch 14/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2458 - accuracy: 0.9312
# Epoch 15/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2176 - accuracy: 0.9563
# Epoch 16/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1878 - accuracy: 0.9688
# Epoch 17/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1663 - accuracy: 0.9625
# Epoch 18/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9750
# Epoch 19/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1338 - accuracy: 0.9750
# Epoch 20/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9750
# Epoch 21/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1172 - accuracy: 0.9688
# Epoch 22/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0965 - accuracy: 0.9750
# Epoch 23/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9812
# Epoch 24/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9750
# Epoch 25/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9750
# Epoch 26/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9875
# Epoch 27/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 0.9812
# Epoch 28/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 0.9875
# Epoch 29/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0506 - accuracy: 0.9875
# Epoch 31/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 0.9937
# Epoch 32/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 1.0000
